# %% [markdown]
# ### Exploratory Data Analisys - EDA

# %%
books = [
    {
        "name": "10-Day Green Smoothie Cleanse",
        "author": "JJ Smith",
        "rating": 4.73,
        "year": 2016,
        "genre": "Non Fiction"
    },
    {
        "name": "11/22/63: A Novel",
        "author": "Stephen King",
        "rating": 4.62,
        "year": 2011,
        "genre": "Fiction"
    },
    {
        "name": "12 Rules for Life",
        "author": "Jordan B. Peterson",
        "rating": 4.69,
        "year": 2018,
        "genre": "Non Fiction"
    },
    {
        "name": "1984 (Signet Classics)",
        "author": "George Orwell",
        "rating": 4.73,
        "year": 2017,
        "genre": "Fiction"
    },
    {
        "name": "5,000 Awesome Facts",
        "author": "National Geographic Kids",
        "rating": 4.81,
        "year": 2019,
        "genre": "Childrens"
    }
]

# %%
import pandas as pd 
df = pd.DataFrame(books)

# %%
df
# Out:
#                             name                    author  rating  year  \
# 0  10-Day Green Smoothie Cleanse                  JJ Smith    4.73  2016
# 1              11/22/63: A Novel              Stephen King    4.62  2011
# 2              12 Rules for Life        Jordan B. Peterson    4.69  2018
# 3         1984 (Signet Classics)             George Orwell    4.73  2017
# 4            5,000 Awesome Facts  National Geographic Kids    4.81  2019
#
#          genre
# 0  Non Fiction
# 1      Fiction
# 2  Non Fiction
# 3      Fiction
# 4    Childrens

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    5 non-null      object
#  1   author  5 non-null      object
#  2   rating  5 non-null      float64
#  3   year    5 non-null      int64
#  4   genre   5 non-null      object
# dtypes: float64(1), int64(1), object(3)
# memory usage: 332.0+ bytes

# %%
df.value_counts('genre')
# Out:
# genre
# Fiction        2
# Non Fiction    2
# Childrens      1
# Name: count, dtype: int64

# %%
df.describe()
# Out:
#          rating         year
# count  5.000000     5.000000
# mean   4.716000  2016.200000
# std    0.069138     3.114482
# min    4.620000  2011.000000
# 25%    4.690000  2016.000000
# 50%    4.730000  2017.000000
# 75%    4.730000  2018.000000
# max    4.810000  2019.000000

# %%
pip install seaborn
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.9/101.9 kB 2.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 2.8 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 4.5 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 326.2/326.2 kB 8.0 MB/s eta 0:00:00ta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 9.4 MB/s eta 0:00:0000:0100:01m
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 8.7 MB/s eta 0:00:00a 0:00:01m
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 8.3 MB/s eta 0:00:0000:0100:01m
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.7/107.7 kB 4.6 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns 
import matplotlib.pyplot as plt 

sns.histplot(data=df, x='rating')

plt.show()

# %%
#check the type of data
df.dtypes
# Out:
# name       object
# author     object
# rating    float64
# year        int64
# genre      object
# dtype: object

# %%
# Updating data types using astype()
df['year'] = df['year'].astype(int)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#check if there are the values in the column using isin() method!
df['genre'].isin(['Fiction', 'Non Fiction'])
# Out:
# 0     True
# 1     True
# 2     True
# 3     True
# 4    False
# Name: genre, dtype: bool

# %%
#But, if you want to have the opposit result, put the ~ in the beginning!
~df['genre'].isin(['Fiction', 'Non Fiction'])
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# Name: genre, dtype: bool

# %%
# Select a new df only contains Fiction and non fiction
df[df['genre'].isin(['Fiction', 'Non Fiction'])]
# Out:
#                             name              author  rating  year  \
# 0  10-Day Green Smoothie Cleanse            JJ Smith    4.73  2016
# 1              11/22/63: A Novel        Stephen King    4.62  2011
# 2              12 Rules for Life  Jordan B. Peterson    4.69  2018
# 3         1984 (Signet Classics)       George Orwell    4.73  2017
#
#          genre
# 0  Non Fiction
# 1      Fiction
# 2  Non Fiction
# 3      Fiction

# %%
## Validating numerical data
df.select_dtypes('number')
# Out:
#    rating  year
# 0    4.73  2016
# 1    4.62  2011
# 2    4.69  2018
# 3    4.73  2017
# 4    4.81  2019

# %%
df['year'].min()
# Out:
# np.int64(2011)

# %%
df['year'].max()
# Out:
# np.int64(2019)

# %% [markdown]
# #### Data Summarization

# %%
df.dtypes
# Out:
# name       object
# author     object
# rating    float64
# year        int64
# genre      object
# dtype: object

# %%
# .groupby() -- groups data by category
df.groupby('genre')[['rating', 'year']].mean()
# Out:
#              rating    year
# genre
# Childrens     4.810  2019.0
# Fiction       4.675  2014.0
# Non Fiction   4.710  2017.0

# %%
df.groupby('genre').mean(numeric_only=True)
# Out:
#              rating    year
# genre
# Childrens     4.810  2019.0
# Fiction       4.675  2014.0
# Non Fiction   4.710  2017.0

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
## Also, it is possible to use .agg() that applies aggregatinf functions across a DataFrame
#df.agg(['mean', 'std'], numeric_only=True)
df.select_dtypes(include=['number']).agg(['mean', 'std'])
# Out:
#         rating         year
# mean  4.716000  2016.200000
# std   0.069138     3.114482

# %%
df.groupby('genre').agg(
    mean_rating=('rating', 'mean'),
    std_rating=('rating', 'std'),
    median_year=('year', 'median')
)
# Out:
#              mean_rating  std_rating  median_year
# genre
# Childrens          4.810         NaN       2019.0
# Fiction            4.675    0.077782       2014.0
# Non Fiction        4.710    0.028284       2017.0

# %%
sns.barplot(data=df, x='genre', y='rating')
plt.show()

# %%
# Print yearly mean and standard deviation grouped by continent
#print(unemployment.groupby('continent').agg(['mean', 'std']))

# %%
# continent_summary = unemployment.groupby("continent").agg(
#     # Create the mean_rate_2021 column
#     mean_rate_2021=('2021','mean'),
#     # Create the std_rate_2021 column
#     std_rate_2021 =('2021', 'std')
# )
# print(continent_summary)

# %% [markdown]
# ### Addressing missing data

# %%
# Checking for missing values
#print(df.isna().sum())

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import pandas as pd

data = {
    "Airline": [
        "Jet Airways", "IndiGo", "IndiGo", "SpiceJet", "Jet Airways", "Jet Airways", 
        "Jet Airways", "Multiple carriers", "Air India", "IndiGo", "Air India", 
        "Jet Airways", "IndiGo", "Air India", "SpiceJet"
    ],
    "Date_of_Journey": [
        "9/06/2019", "12/05/2019", "01/03/2019", "24/06/2019", "12/03/2019", 
        "01/03/2019", "12/03/2019", "27/05/2019", "1/06/2019", "18/04/2019", 
        "24/06/2019", "9/06/2019", "24/04/2019", "3/03/2019", "15/04/2019"
    ],
    "Source": [
        "Delhi", "Kolkata", "Banglore", "Kolkata", "Banglore", "Banglore", 
        "Banglore", "Delhi", "Delhi", "Kolkata", "Chennai", "Kolkata", 
        "Kolkata", "Delhi", "Delhi"
    ],
    "Destination": [
        "Cochin", "Banglore", "New Delhi", "Banglore", "New Delhi", "New Delhi",
        "New Delhi", "Cochin", "Cochin", "Banglore", "Kolkata", "Banglore",
        "Banglore", "Cochin", "Cochin"
    ],
    "Route": [
        "DEL → LKO → BOM → COK", "CCU → NAG → BLR", "BLR → NAG → DEL",
        "CCU → BLR", "BLR → BOM → DEL", "BLR → BOM → DEL", "BLR → BOM → DEL",
        "DEL → BOM → COK", "DEL → AMD → BOM → COK", "CCU → BLR", "MAA → CCU",
        "CCU → BOM → BLR", "CCU → BLR", "DEL → AMD → BOM → COK", "DEL → PNQ → COK"
    ],
    "Arrival_Time": [
        "04:25 10 Jun", "23:30", "04:45", "11:25", "10:25 13 Mar",
        "05:05 02 Mar", "10:25 13 Mar", "19:15", "03:30 13 Jun", "22:55",
        "13:55", "09:20 10 May", "19:50", "19:15 04 Mar", "13:15"
    ],
    "Duration": [
        "19h", "5h 25m", "4h 45m", "2h 25m", "15h 30m",
        "15h 30m", "25h 30m", "7h 50m", "13h 15m", "2h 35m",
        "2h 15m", "12h 10m", "2h 35m", "26h 35m", "4h 30m"
    ],
    "Total_Stops": [
        "2 stops", "1 stop", "1 stop", "non-stop", "1 stop",
        "1 stop", "1 stop", "1 stop", "1 stop", "non-stop",
        "non-stop", "1 stop", "non-stop", "2 stops", "1 stop"
    ],
    "Additional_Info": [
        "No info", "No info", "No info", "No info", "In-flight meal not included",
        "No info", "In-flight meal not included", "No info", "No info",
        "No info", "No info", "No info", "No info", "No info", "No info"
    ],
    "Price": [
        13882.0, 6218.0, 13302.0, 3873.0, 11087.0,
        22270.0, 11087.0, 8625.0, 8907.0, 4174.0,
        4667.0, 9663.0, 4804.0, 14011.0, 5830.0
    ]
}

df2 = pd.DataFrame(data)

# %%
df2.head(3)
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 1       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 2       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#    Arrival_Time Duration Total_Stops Additional_Info    Price
# 0  04:25 10 Jun      19h     2 stops         No info  13882.0
# 1         23:30   5h 25m      1 stop         No info   6218.0
# 2         04:45   4h 45m      1 stop         No info  13302.0

# %%
# Count the number of missing values in each column
print(df2.isna().sum())
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              0
# Arrival_Time       0
# Duration           0
# Total_Stops        0
# Additional_Info    0
# Price              0
# dtype: int64

# %%
# Count the number of missing values in each column
print(df2.isna().sum())

# Find the five percent threshold
threshold = len(df2) * 0.05

# Create a filter
cols_to_drop = df2.columns[df2.isna().sum() <= threshold]

# Drop missing values for columns below the threshold
df2.dropna(subset=cols_to_drop, inplace=True)

print(df2.isna().sum())
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              0
# Arrival_Time       0
# Duration           0
# Total_Stops        0
# Additional_Info    0
# Price              0
# dtype: int64
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              0
# Arrival_Time       0
# Duration           0
# Total_Stops        0
# Additional_Info    0
# Price              0
# dtype: int64

# %%
# Check the values of the Additional_Info column
print(df2["Additional_Info"].value_counts())
# Out:
# Additional_Info
# No info                        13
# In-flight meal not included     2
# Name: count, dtype: int64

# %%
# Create a box plot of Price by Airline
sns.boxplot(data=df2, x='Price', y='Airline')

plt.show()

# %%
# Calculate median plane ticket prices by Airline
airline_prices = df2.groupby("Airline")["Price"].median()

print(airline_prices)
# Out:
# Airline
# Air India             8907.0
# IndiGo                5511.0
# Jet Airways          11087.0
# Multiple carriers     8625.0
# SpiceJet              4851.5
# Name: Price, dtype: float64

# %%
# Convert to a dictionary
prices_dict = airline_prices.to_dict()

# Map the dictionary to the missing values
df2["Price"] = df2["Price"].fillna(df2["Airline"].map(prices_dict))

# Check for missing values
print(df2.isna().sum())
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              0
# Arrival_Time       0
# Duration           0
# Total_Stops        0
# Additional_Info    0
# Price              0
# dtype: int64

# %% [markdown]
# #### Converting and analyzing categorical data

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Filter the DataFrame for object columns
non_numeric = df2.select_dtypes('object')

# Loop through columns
for col in non_numeric.columns:
  
  # Print the number of unique values
  print(f"Number of unique values in {col} column: ", non_numeric[col].nunique())
# Out:
# Number of unique values in Airline column:  5
# Number of unique values in Date_of_Journey column:  11
# Number of unique values in Source column:  4
# Number of unique values in Destination column:  4
# Number of unique values in Route column:  10
# Number of unique values in Arrival_Time column:  14
# Number of unique values in Duration column:  13
# Number of unique values in Total_Stops column:  3
# Number of unique values in Additional_Info column:  2

# %%
# Create a list of categories
flight_categories = ['Short-haul', 'Medium', 'Long-haul']

# %%
# Create a list of categories
flight_categories = ["Short-haul", "Medium", "Long-haul"]

# Create short_flights
short_flights = "^0h|^1h|^2h|^3h|^4h"

# Create medium_flights
medium_flights = "^5h|^6h|^7h|^8h|^9h"

# Create long_flights
long_flights = "10h|11h|12h|13h|14h|15h|16h"

# %%
import numpy as np

# Create conditions for values in flight_categories to be created
conditions = [
    (df2["Duration"].str.contains(short_flights)),
    (df2["Duration"].str.contains(medium_flights)),
    (df2["Duration"].str.contains(long_flights))
]

# Apply the conditions list to the flight_categories
df2["Duration_Category"] = np.select(conditions, 
                                        flight_categories,
                                        default="Extreme duration")

# Plot the counts of each category
sns.countplot(data=df2, x="Duration_Category")
plt.show()

# %% [markdown]
# ### Working with numeric data

# %%
print(df2.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Airline            15 non-null     object
#  1   Date_of_Journey    15 non-null     object
#  2   Source             15 non-null     object
#  3   Destination        15 non-null     object
#  4   Route              15 non-null     object
#  5   Arrival_Time       15 non-null     object
#  6   Duration           15 non-null     object
#  7   Total_Stops        15 non-null     object
#  8   Additional_Info    15 non-null     object
#  9   Price              15 non-null     float64
#  10  Duration_Category  15 non-null     object
# dtypes: float64(1), object(10)
# memory usage: 1.4+ KB
# None

# %%
# # Preview the column
# print(df2["Duration"].head())

# # Remove the string character
# df2["Duration"] = df2["Duration"].astype(str).str.replace("h", "")
# # Remove the string character
# df2["Duration"] = df2["Duration"].astype(str).str.replace("m", "")

# # Convert to float data type
# df2["Duration"] = df2["Duration"].astype(float)

# # Plot a histogram
# sns.histplot(data=df2, x="Duration")
# plt.show()

# %% [markdown]
# ### Outliers

# %%
# Plot a histogram of flight prices
sns.histplot(data=df2, x='Price')
plt.show()

# %%
# Display descriptive statistics for flight duration
print(df2['Duration'].describe())
# Out:
# count         15
# unique        13
# top       15 30m
# freq           2
# Name: Duration, dtype: object

# %% [markdown]
# #### Patters over time

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# divorce['marriage_date'] = pd.to_datetime(divorce['month', 'day', 'year'])

# %% [markdown]
# Vai te retornar uma data formatada, desde que você tenha as colunas indicadas.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import pandas as pd

data = {
    "divorce_date": [
        "2006-09-06", "2008-01-02", "2011-01-02", "2011-01-02", "2011-01-02", 
        "2012-01-06", "2005-01-03", "2005-01-03", "2006-01-03", "2007-01-03", 
        "2007-01-03", "2010-01-03", "2011-01-03", "2003-01-04", "2002-01-04",
        "2003-01-04", "2009-01-04", "2009-01-04", "2009-01-04", "2009-01-04",
        "2001-01-06", "2001-01-06", "2003-01-06", "2010-01-06", "2011-01-06"
    ],
    "dob_man": [
        "1975-12-18", "1976-11-17", "1969-04-06", "1979-11-13", "1982-09-20",
        "1973-09-07", "1978-09-07", "1974-07-02", "1964-03-04", "1961-09-26",
        "1987-05-04", "1968-05-31", "1981-09-25", "1968-09-05", "1977-12-17",
        "1964-11-14", "1966-02-25", "1955-10-15", "1955-04-19", "1955-04-19",
        "1966-03-21", "1976-10-03", "1966-03-21", "1989-10-19", "1978-10-04"
    ],
    "education_man": [
        "Secondary", "Professional", "Preparatory", "Secondary", "Professional",
        "Professional", "Secondary", "Preparatory", "Professional", "Professional",
        "Preparatory", "Professional", "Preparatory", "Primary", "Primary",
        "Professional", "Secondary", "Professional", "Professional", "Professional",
        "Professional", "Professional", "Professional", "Professional", "Professional"
    ],
    "income_man": [
        2000.0, 6000.0, 5000.0, 12000.0, 6000.0,
        20000.0, 5600.0, 3500.0, 12000.0, 2000.0,
        2000.0, 5000.0, 1700.0, 2000.0, 2000.0,
        14000.0, 5000.0, 10000.0, 15000.0, 12000.0,
        1500.0, 1500.0, 12000.0, 4000.0, 6000.0
    ],
    "dob_woman": [
        "1983-08-01", "1977-07-13", "1970-02-16", "1981-05-13", "1988-01-30",
        "1974-05-20", "1969-05-25", "1967-03-19", "1976-08-20", "1962-05-17",
        "1986-09-21", "1976-08-16", "1979-06-06", "1967-07-06", "1975-07-08",
        "1970-11-17", "1965-01-14", "1963-11-26", "1969-06-19", "1969-06-19",
        "1976-10-06", "1976-10-06", "1966-10-06", "1985-05-25", "1977-07-01"
    ],
    "education_woman": [
        "Secondary", "Professional", "Professional", "Secondary", "Professional",
        "Professional", "Secondary", "Preparatory", "Professional", "Professional",
        "Preparatory", "Professional", "Preparatory", "Preparatory", "Secondary",
        "Professional", "Professional", "Professional", "Professional", "Professional",
        "Professional", "Professional", "Professional", "Professional", "Professional"
    ],
    "income_woman": [
        1800.0, 6000.0, 5000.0, 12000.0, 10000.0,
        15.0, 4500.0, 4000.0, 7000.0, 4000.0,
        2000.0, 3800.0, 5000.0, 3400.0, 1600.0,
        4200.0, 6500.0, 7000.0, 8000.0, 8000.0,
        3000.0, 3000.0, 3000.0, 4000.0, 6000.0
    ],
    "marriage_date": [
        "2000-06-26", "2001-09-02", "2000-02-02", "2006-05-13", "2007-08-06",
        "2000-03-08", "1991-10-09", "1993-01-02", "1998-12-11", "1987-03-19",
        "2005-07-12", "2002-03-22", "2008-08-02", "1989-05-26", "1996-04-15",
        "2001-05-30", "1985-12-04", "1986-01-27", "2001-04-21", "2000-11-27",
        "2000-10-14", "2000-10-14", "1998-11-28", "2002-02-16", "2009-08-15"
    ],
    "marriage_duration": [
        5.0, 7.0, 2.0, 2.0, 3.0,
        11.0, 10.0, 10.0, 7.0, 19.0,
        4.0, 3.0, 3.0, 12.0, 6.0,
        5.0, 23.0, 22.0, 7.0, 5.0,
        3.0, 3.0, 5.0, 1.0, 1.0
    ],
    "num_kids": [
        1.0, None, 2.0, None, None,
        None, 2.0, 2.0, 1.0, 3.0,
        None, 1.0, None, 2.0, None,
        1.0, None, 2.0, None, None,
        None, None, 1.0, None, None
    ]
}

divorce = pd.DataFrame(data)

# %%
divorce.dtypes
# Out:
# divorce_date          object
# dob_man               object
# education_man         object
# income_man           float64
# dob_woman             object
# education_woman       object
# income_woman         float64
# marriage_date         object
# marriage_duration    float64
# num_kids             float64
# dtype: object

# %%
divorce['marriage_date'] = pd.to_datetime(divorce['marriage_date'])

# %%
divorce.dtypes
# Out:
# divorce_date                 object
# dob_man                      object
# education_man                object
# income_man                  float64
# dob_woman                    object
# education_woman              object
# income_woman                float64
# marriage_date        datetime64[ns]
# marriage_duration           float64
# num_kids                    float64
# dtype: object

# %%
divorce.dtypes

# %%
divorce['divorce_date'] = pd.to_datetime(divorce['divorce_date'])

# %%
divorce['dob_man'] = pd.to_datetime(divorce['dob_man'])

# %%
divorce['dob_woman'] = pd.to_datetime(divorce['dob_woman'])

# %% [markdown]
# ### Correlation

# %%
#divorce.corr()

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - divorce['divorce_date'].min()
# - divorce['divorce_date'].max()

# %% [markdown]
# ### Factor relationships and distributions

# %%
divorce['education_man'].value_counts()
# Out:
# education_man
# Professional    15
# Secondary        4
# Preparatory      4
# Primary          2
# Name: count, dtype: int64

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
sns.kdeplot(data=divorce, x='marriage_duration', hue='education_man')
# Out:
# <Axes: xlabel='marriage_duration', ylabel='Density'>

# %%
sns.kdeplot(data=divorce, x='marriage_duration', hue='education_man', cut=0)
# Out:
# <Axes: xlabel='marriage_duration', ylabel='Density'>

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# # Update the KDE plot to show a cumulative distribution function
# sns.kdeplot(data=divorce, x="marriage_duration", hue="num_kids", cut=0, cumulative=True)
# plt.show()
# Out:
# /tmp/ipykernel_97333/3553037189.py:2: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(data=divorce, x="marriage_duration", hue="num_kids", cut=0)

# %% [markdown]
# ### Considerations for categorical data

# %% [markdown]
# Cross-tabulation

# %% [markdown]
# #### Generating new features

# %% [markdown]
# ![image.png](attachment:image.png)
