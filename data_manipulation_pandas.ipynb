# %% [markdown]
# ## DataFrames

# %% [markdown]
# .head()
# .describe()
# df.columns

# %% [markdown]
# df.sort_values('column')

# %%
#df.sort_values('column', ascending = False)

# %%
#df.sort_values(['column1', 'column2'], ascending = [False, True])

# %%
#para ver os valores de uma coluna
#df['name']

# %%
#mais de cuma coluna
#df[['name', 'altura']]

# %%
#condiacao booleana:
#df['altura'] > 50
#O output aqui vai ser apenas true ou false

# %%
# Me retorna um dataframe com essa condicao
# df[df['altura'] > 50]

# %%
# Filtrar um dataframe baseado em data
# df[df['data_nascimento] < '2025-01-01']

# %%
# .isin()
# is_black_or_brown = dogs['color'].isin(['Black', 'Brown'])
#dogs['is_black_or_brown']

# %% [markdown]
# #### Novas Colunas

# %%
#df['altura_metros'] = df['altura_cm'] / 100

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
data = {
    "region": ["East South Central", "Pacific", "Mountain", "West South Central", "Pacific", "Mountain"],
    "state": ["Alabama", "Alaska", "Arizona", "Arkansas", "California", "Colorado"],
    "individuals": [2570.0, 1434.0, 7259.0, 2288.0, 109008.0, 7607.0],
    "family_members": [864.0, 582.0, 2606.0, 432.0, 20964.0, 3250.0],
    "state_pop": [4887681, 735139, 7158024, 3009733, 39461588, 5691287],
    "total": [3434.0, 2016.0, 9865.0, 2712.0, 129972.0, 10857.0],
    "p_individuals": [0.748, 0.711, 0.736, 0.841, 0.839, 0.701]
}

# %%
import pandas as pd 

df = pd.DataFrame(data)

# %%
df
# Out:
#                region       state  individuals  family_members  state_pop  \
# 0  East South Central     Alabama       2570.0           864.0    4887681
# 1             Pacific      Alaska       1434.0           582.0     735139
# 2            Mountain     Arizona       7259.0          2606.0    7158024
# 3  West South Central    Arkansas       2288.0           432.0    3009733
# 4             Pacific  California     109008.0         20964.0   39461588
# 5            Mountain    Colorado       7607.0          3250.0    5691287
#
#       total  p_individuals
# 0    3434.0          0.748
# 1    2016.0          0.711
# 2    9865.0          0.736
# 3    2712.0          0.841
# 4  129972.0          0.839
# 5   10857.0          0.701
